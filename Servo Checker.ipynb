# %%
max_s =2400
min_s = 500

min_a = 0
max_a = 180

m = (max_s-min_s)/(max_a - min_a)
b = min_s

def time_s(angle):
    return (m*angle + b)

print (time_s(150))
print (time_s(90))
print (time_s(40))
print (time_s(20))
print (time_s(0))
# Out:
# 2083.333333333333
# 1450.0
# 922.2222222222222
# 711.1111111111111
# 500.0
